# %% [markdown]
# ## What is Makemore:
# - makes more of things that you give it
# - eg: give it a bunch of names, and it will create new unique names like the ones that you give it
# - character-level language model (each word is an example treated as sequences of characters) - it learns and predicts what should be the next character in a sequence (Bigram)
